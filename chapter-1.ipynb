# %%
# %pip install numpy matplotlib pandas sympy

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import sympy
from sympy import symbols, plot, root

# %%
# This makes your plots look high-quality and modern
plt.style.use('seaborn-v0_8-muted')
# %matplotlib inline

# %%
# 1. Define the range of x values (from -5 to 5)
x = np.linspace(-5, 5, 100)

# 2. Define the function
y = x**2 - 4

# 3. Create the plot
plt.figure(figsize=(8, 5))
plt.plot(x, y, label='f(x) = x^2 - 4', color='blue')
plt.axhline(0, color='black', linewidth=0.8) # x-axis
plt.axvline(0, color='black', linewidth=0.8) # y-axis
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.title("Graph of a Quadratic Function")
plt.show()

# %% [markdown]
# ### Piecewise Function Definition
# The function is defined as:
# $$f(x) = \begin{cases} x^2 & \text{if } x < 0 \\ x & \text{if } x \geq 0 \end{cases}$$
#
# **Note:** This function is continuous at $x=0$.

# %% [markdown]
# Use function notation to express the weight of a pig in pounds as a function of its age in days

# %%
## Pigs grow 1.5kg per day
growth = 1.5
days = [50, 70, 80]

def weight_as_function_of_age(days):
    # enumerate gives us the index (starting at 0) and the value
    for index, day in enumerate(days):
        weight = day * growth
        # In Python, we use print() and f-strings start with f""
        print(f"pig number {index} has been growing for {day} days and so weighs {weight} Kilograms")

weight_as_function_of_age(days)

# %%
growth = 1.5
days = [50, 70, 80]

def seasonal_weight_function(days):
    for index, day in enumerate(days):
        # math.sin(day) oscillates between -1 and 1.
        # This simulates the pig eating more or less depending on the 'season'
        seasonal_factor = math.sin(day) 
        weight = day * (growth + seasonal_factor)
        
        print(f"pig number {index}:")
        print(f"  - Age: {day} days")
        print(f"  - Seasonal Factor: {seasonal_factor:.2f}")
        print(f"  - Total Weight: {weight:.2f} kg\n")

seasonal_weight_function(days)

# %%
# 1. Setup Data
# We use np.linspace to create 100 smooth points between day 0 and 100
days = np.linspace(0, 100, 500) 
growth_rate = 1.5

# 2. Define the Mathematical Functions
linear_growth = days * growth_rate
# We multiply the sine wave by 10 to make the 'wiggles' visible
seasonal_growth = days * (growth_rate + 0.2 * np.sin(days / 5))

# 3. Create the Plot
plt.figure(figsize=(10, 6))

# Plot the Linear Trend (The 'Expected' Growth)
plt.plot(days, linear_growth, label='Linear Growth (Expected)', linestyle='--', color='gray')

# Plot the Seasonal Trend (The 'Real-World' Growth)
plt.plot(days, seasonal_growth, label='Seasonal Growth (Actual)', color='blue', linewidth=2)

# 4. Add Labels (The 'Metadata')
plt.title("Pig Growth Modeling: Pre-Calculus in Action", fontsize=14)
plt.xlabel("Days Since Birth")
plt.ylabel("Weight (kg)")
plt.legend()
plt.grid(True, alpha=0.3)

# 5. Show it!
plt.show()

# %%
def h(p): 
    x = (p ** 2) + (p * 2)
    print(x)

h(3)

# %%
# 1. Define the function (as we did before)
def h(p):
    return p**2 + 2 * p


# 2. Create an array of 'p' values (the x-axis)
# This creates 400 points between -10 and 10
p_values = np.linspace(-5, 5, 10)

# 3. Calculate the 'h(p)' values for every p (the y-axis)
h_values = h(p_values)

# 4. Create the plot
plt.figure(figsize=(8, 6))
plt.plot(p_values, h_values, label="$h(p) = p^2 + 2p$", color="blue")

plt.axhline(y=1, color="red", linestyle="--", label="y = 1")

# This creates a list of integers from -5 to 5 for the x-axis
plt.xticks(np.arange(-5, 6, 1))

# This creates a list of integers from the bottom to the top of your data
# h(-1) is -1 and h(5) is 35, so we set a reasonable range:
plt.yticks(np.arange(-2, 35, 5))

# 5. Add labels and a grid for readability
plt.title("Graph of the Function h(p)")
plt.xlabel("p (Input)")
plt.ylabel("h(p) (Output)")
plt.axhline(0, color="black", linewidth=1)  # Adds the x-axis line
plt.axvline(0, color="black", linewidth=1)  # Adds the y-axis line
plt.grid(True, linestyle="--")
plt.legend()

# 6. Show the graph
plt.show()

# %%
def solve_for_x(y):
    """
    Solves x - 8y^3 = 0 for x.
    Rearranged: x = 8 * y^3
    """
    return 8 * (y**3)


# Example usage:
result = solve_for_x(2)
print(f"When y is 2, x is {result}")

import matplotlib.pyplot as plt
import numpy as np

# 1. Define the range for x
x = np.linspace(-20, 20, 500)

# 2. Calculate y (solving x - 8y^3 = 0 for y)
# y = (x / 8)^(1/3) = x^(1/3) / 2
# We use np.sign and np.abs to handle negative numbers properly
y = np.sign(x) * (np.abs(x) ** (1 / 3)) / 2

# 3. Create the plot
plt.figure(figsize=(10, 6))
plt.plot(x, y, label=r"$y = \frac{\sqrt[3]{x}}{2}$", color="royalblue", linewidth=2)

# 4. Styling (making it look professional)
plt.axhline(0, color="black", linewidth=1)
plt.axvline(0, color="black", linewidth=1)
plt.grid(True, linestyle="--", alpha=0.6)
plt.title("Visualization of the Cubic Activation Function", fontsize=14)
plt.xlabel("Input (x)", fontsize=12)
plt.ylabel("Output (y)", fontsize=12)
plt.legend()

# 5. Display/Save
plt.savefig("cubic_root_plot.png")

# %%
x = symbols("x")
# This will render the math and the graph directly in your notebook cell
p = plot(
    root(x, 3) / 2,
    (x, -20, 20),
    title="Function Plot: $y = \\sqrt[3]{x}/2$",
    xlabel="x",
    ylabel="y",
    line_color="red",
    show=False,
)
p.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define domains
domains = [(-0.1, 0.1), (-10, 10), (-100, 100)]

plt.figure(figsize=(12, 4))

for i, (a, b) in enumerate(domains, 1):
    x = np.linspace(a, b, 500)
    y = x**2

    plt.subplot(1, 3, i)
    plt.plot(x, y)
    plt.title(f"Domain: [{a}, {b}]")
    plt.xlabel("x")
    plt.ylabel("y = x^2")

    # Range is [0, max(x^2)]
    y_min = 0
    y_max = max(a**2, b**2)
    plt.text(
        0.5,
        0.9,
        f"Range: [{y_min}, {y_max}]",
        transform=plt.gca().transAxes,
        ha="center",
    )

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# Define the function
def f(x):
    return np.cbrt(x)


# Define the domains from the exercises
domains = [(-0.001, 0.001), (-1000, 1000), (-1000000, 1000000)]

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
fig.suptitle("Graphing $y = \sqrt[3]{x}$ on different domains", fontsize=16)

for i, (start, end) in enumerate(domains):
    x = np.linspace(start, end, 1000)
    y = f(x)

    axes[i].plot(x, y, color="teal", linewidth=2)
    axes[i].set_title(f"Domain: [{start}, {end}]")
    axes[i].set_xlabel("x")
    axes[i].set_ylabel("y")
    axes[i].grid(True, linestyle="--", alpha=0.7)

    # Highlight the range endpoints
    axes[i].scatter([start, end], [f(start), f(end)], color="red")

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# ---- Define parameters ----
b = 5  # change as needed
h = 3  # change as needed


# ---- Define functions ----
def f(x):
    return 4 * x**2 - 7


def g(x):
    return 2 * x**2 - 9


def p(x):
    return 3 * x + 4


# ---- Create x ranges ----
x_f = np.linspace(1, b, 100)
x_g = np.linspace(4, b, 100)
x_p = np.linspace(2, 2 + h, 100)

# ---- Plot ----
plt.figure(figsize=(8, 6))

plt.plot(x_f, f(x_f), label="f(x) = 4x² - 7 on [1, b]")
plt.plot(x_g, g(x_g), label="g(x) = 2x² - 9 on [4, b]")
plt.plot(x_p, p(x_p), label="p(x) = 3x + 4 on [2, 2 + h]")

# ---- Styling ----
plt.xlabel("x")
plt.ylabel("y")
plt.title("Graphs of f, g, and p")
plt.legend()
plt.grid()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

b = 5
h = 3

# x ranges
x_f = np.linspace(1, b, 100)
x_g = np.linspace(4, b, 100)
x_p = np.linspace(2, 2 + h, 100)

# derivatives
df = 8 * x_f
dg = 4 * x_g
dp = np.full_like(x_p, 3)

plt.figure(figsize=(8, 6))

plt.plot(x_f, df, label="f'(x) = 8x")
plt.plot(x_g, dg, label="g'(x) = 4x")
plt.plot(x_p, dp, label="p'(x) = 3")

plt.title("Rate of Change (Derivatives)")
plt.xlabel("x")
plt.ylabel("Rate of Change")
plt.legend()
plt.grid()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# Define the function
def h(x):
    return x**5 + 5 * x**4 + 10 * x**3 + 10 * x**2 - 1


# Create x values
x = np.linspace(-5, 2, 400)  # range chosen to show shape clearly
y = h(x)

# Plot
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="h(x) = x^5 + 5x^4 + 10x^3 + 10x^2 - 1")

plt.axhline(0)  # x-axis
plt.axvline(0)  # y-axis

plt.xlabel("x")
plt.ylabel("y")
plt.title("Graph of h(x)")
plt.legend()
plt.grid()

plt.show()
